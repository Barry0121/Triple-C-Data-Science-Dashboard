# %% [markdown]
# # Zillow Data Collection & Cleaning

# %% [markdown]
# ### Data Collection

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import os

# %%
def parse_house():
    url = 'https://www.zillow.com/search/GetSearchPageState.htm'

    headers = {
        'Accept': '*/*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9',
        'upgrade-insecure-requests': '1',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36'
    }
    
    houses = []
    for page in range(1, 3):
        params = {
            "searchQueryState": json.dumps({
                "pagination": {"currentPage": page},
                "usersSearchTerm": "La Jolla, San Diego, CA",
                "mapBounds": {
                    "west":-117.31402417204882,
                    "east":-117.19557782195116,
                    "south":32.8007253011325,
                    "north":32.89504192800182
                },
                "mapZoom": 13,
                "regionSelection": [
                    {
                        "regionId":46087,"regionType":8
                    }
                ],
                "isMapVisible": False,
                "filterState": {
                    "fore":{"value":False},
                    "mf":{"value":False},
                    "ah":{"value":True},
                    "auc":{"value":False},
                    "nc":{"value":False},
                    "fr":{"value":True},
                    "land":{"value":False},
                    "manu":{"value":False},
                    "fsbo":{"value":False},
                    "cmsn":{"value":False},
                    "fsba":{"value":False}},
                    "isListVisible":True
            }),
            "wants": json.dumps(
                {
                    "cat1": ["listResults"]
                }
            ),
            "requestId": 3
        }

        # send request
        page = requests.get(url, headers=headers, params=params)

        # get json data
        json_data = page.json()

        # loop via data
        for house in json_data['cat1']['searchResults']['listResults']:
            houses.append(house)
    # show data
    print('Total houses - {}'.format(len(houses)))

# %%
def

# %%
url = 'https://www.zillow.com/search/GetSearchPageState.htm'

headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'upgrade-insecure-requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36'
}

# %%
houses = []
for page in range(1, 3):
    params = {
        "searchQueryState": json.dumps({
            "pagination": {"currentPage": page},
            "usersSearchTerm": "La Jolla, San Diego, CA",
            "mapBounds": {
                "west":-117.31402417204882,
                "east":-117.19557782195116,
                "south":32.8007253011325,
                "north":32.89504192800182
            },
            "mapZoom": 13,
            "regionSelection": [
                {
                    "regionId":46087,"regionType":8
                }
            ],
            "isMapVisible": False,
            "filterState": {
                "fore":{"value":False},
                "mf":{"value":False},
                "ah":{"value":True},
                "auc":{"value":False},
                "nc":{"value":False},
                "fr":{"value":True},
                "land":{"value":False},
                "manu":{"value":False},
                "fsbo":{"value":False},
                "cmsn":{"value":False},
                "fsba":{"value":False}},
                "isListVisible":True
        }),
        "wants": json.dumps(
            {
                "cat1": ["listResults"]
            }
        ),
        "requestId": 3
    }

    # send request
    page = requests.get(url, headers=headers, params=params)

    # get json data
    json_data = page.json()

    # loop via data
    for house in json_data['cat1']['searchResults']['listResults']:
        houses.append(house)
# show data
print('Total houses - {}'.format(len(houses)))
# Out:
# Total houses - 59

# %% [markdown]
# All of the data are stored in JSON but there are two different formats

# %%
keys = houses[0].keys()
diff = []
for i in range(len(houses)):
    if keys != houses[i].keys():
        diff.append(i)
diff
# Out:
# [4, 5, 8, 9, 11, 12, 20, 44]

# %%
# Format 1 ex
houses[0]
# Out:
# {'zpid': '16856693',
#  'id': '16856693',
#  'providerListingId': '3gqf6q9qsgqb2',
#  'imgSrc': 'https://photos.zillowstatic.com/fp/0243699851ec2be4704ad2d146ea17a8-p_e.jpg',
#  'hasImage': True,
#  'detailUrl': 'https://www.zillow.com/homedetails/1656-Bahia-Vista-Way-La-Jolla-CA-92037/16856693_zpid/',
#  'statusType': 'FOR_RENT',
#  'statusText': 'House for rent',
#  'countryCurrency': '$',
#  'price': '$9,100/mo',
#  'unformattedPrice': 9100,
#  'address': '1656 Bahia Vista Way, La Jolla, CA 92037',
#  'addressStreet': '1656 Bahia Vista Way',
#  'addressCity': 'La Jolla',
#  'addressState': 'CA',
#  'addressZipcode': '92037',
#  'isUndisclosedAddress': False,
#  'beds': 3,
#  'baths': 2.0,
#  'area': 2843,
#  'latLong': {'latitude': 32.816788, 'longitude': -117.2547},
#  'isZillowOwned': False,
#  'variableData': {'type': 'TIME_ON_INFO',
#   'text': '1 hour ago',
#   'data': {'isFresh': True}},
#  'badgeInfo': None,
#  'hdpData': {'homeInfo': {'zpid': 16856693,
#    'streetAddress': '1656 Bahia Vista Way',
#    'zipcode': '92037',
#    'city': 'La Jolla',
#    'state': 'CA',
#    'latitude': 32.816788,
#    'longitude': -117.2547,
#    'price': 9100.0,
#    'bathrooms': 2.0,
#    'bedrooms': 3.0,
#    'livingArea': 2843.0,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'FOR_RENT',
#    'daysOnZillow': -1,
#    'isFeatured': False,
#    'shouldHighlight': False,
#    'isRentalWithBasePrice': False,
#    'zestimate': 2609400,
#    'rentZestimate': 8139,
#    'listing_sub_type': {},
#    'isUnmappable': False,
#    'isPreforeclosureAuction': False,
#    'homeStatusForHDP': 'FOR_RENT',
#    'priceForHDP': 9100.0,
#    'isNonOwnerOccupied': True,
#    'isPremierBuilder': False,
#    'isZillowOwned': False,
#    'currency': 'USD',
#    'country': 'USA',
#    'taxAssessedValue': 265693.0,
#    'lotAreaValue': 3.0,
#    'lotAreaUnit': 'acres'}},
#  'isSaved': False,
#  'isUserClaimingOwner': False,
#  'isUserConfirmedClaim': False,
#  'pgapt': 'ForRent',
#  'sgapt': 'For Rent',
#  'zestimate': 2609400,
#  'shouldShowZestimateAsPrice': False,
#  'has3DModel': False,
#  'hasVideo': False,
#  'isHomeRec': False,
#  'hasAdditionalAttributions': False,
#  'isFeaturedListing': False,
#  'availabilityDate': None,
#  'list': True,
#  'relaxed': False}

# %%
# Format 2 ex
houses[5]
# Out:
# {'zpid': '32.86568--117.235725',
#  'id': '32.86568--117.235725',
#  'lotId': 1001554478,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/c16331bf1bedb76f67c612d72e8a00a0-p_e.jpg',
#  'hasImage': True,
#  'statusType': 'FOR_RENT',
#  'statusText': 'Solazzo Apartments Homes',
#  'detailUrl': '/b/solazzo-apartments-homes-la-jolla-ca-5Xk5YK/',
#  'latLong': {'latitude': 32.86568, 'longitude': -117.235725},
#  'units': [{'price': '$2,830+', 'beds': '1'}],
#  'variableData': {'type': 'TIME_ON_INFO', 'text': 'Updated today'},
#  'badgeInfo': None,
#  'buildingName': 'Solazzo Apartments Homes',
#  'isBuilding': True,
#  'address': '8506 Villa La Jolla Dr, La Jolla, CA',
#  'addressStreet': '8506 Villa La Jolla Dr   # 281',
#  'addressState': 'CA',
#  'addressCity': 'La Jolla',
#  'addressZipcode': '92037',
#  'providerListingId': '12e0rmdse6tpe',
#  'canSaveBuilding': True,
#  'has3DModel': False,
#  'isFeaturedListing': True,
#  'isSaved': False,
#  'list': True,
#  'relaxed': False}

# %%
# Format 2 ex
houses[6]
# Out:
# {'zpid': '16848965',
#  'id': '16848965',
#  'providerListingId': '2eamy58sb36ta',
#  'imgSrc': 'https://photos.zillowstatic.com/fp/d9c0f3aa2dd64dff8dcc1a9b99b6b6fe-p_e.jpg',
#  'hasImage': True,
#  'detailUrl': 'https://www.zillow.com/homedetails/7428-Eads-Ave-La-Jolla-CA-92037/16848965_zpid/',
#  'statusType': 'FOR_RENT',
#  'statusText': 'House for rent',
#  'countryCurrency': '$',
#  'price': '$7,300/mo',
#  'unformattedPrice': 7300,
#  'address': '7428 Eads Ave, La Jolla, CA 92037',
#  'addressStreet': '7428 Eads Ave',
#  'addressCity': 'La Jolla',
#  'addressState': 'CA',
#  'addressZipcode': '92037',
#  'isUndisclosedAddress': False,
#  'beds': 3,
#  'baths': 3.5,
#  'area': 1164,
#  'latLong': {'latitude': 32.838898, 'longitude': -117.27495},
#  'isZillowOwned': False,
#  'variableData': {'type': 'TIME_ON_INFO',
#   'text': 'Updated yesterday',
#   'data': {'isFresh': True}},
#  'badgeInfo': None,
#  'hdpData': {'homeInfo': {'zpid': 16848965,
#    'streetAddress': '7428 Eads Ave',
#    'zipcode': '92037',
#    'city': 'La Jolla',
#    'state': 'CA',
#    'latitude': 32.838898,
#    'longitude': -117.27495,
#    'price': 7300.0,
#    'bathrooms': 3.5,
#    'bedrooms': 3.0,
#    'livingArea': 1164.0,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'FOR_RENT',
#    'daysOnZillow': -1,
#    'isFeatured': False,
#    'shouldHighlight': False,
#    'isRentalWithBasePrice': False,
#    'zestimate': 1722300,
#    'rentZestimate': 4910,
#    'listing_sub_type': {},
#    'isUnmappable': False,
#    'isPreforeclosureAuction': False,
#    'homeStatusForHDP': 'FOR_RENT',
#    'priceForHDP': 7300.0,
#    'isNonOwnerOccupied': True,
#    'isPremierBuilder': False,
#    'isZillowOwned': False,
#    'currency': 'USD',
#    'country': 'USA',
#    'taxAssessedValue': 810881.0,
#    'lotAreaValue': 7765.0,
#    'lotAreaUnit': 'sqft'}},
#  'isSaved': False,
#  'isUserClaimingOwner': False,
#  'isUserConfirmedClaim': False,
#  'pgapt': 'ForRent',
#  'sgapt': 'For Rent',
#  'zestimate': 1722300,
#  'shouldShowZestimateAsPrice': False,
#  'has3DModel': False,
#  'hasVideo': False,
#  'isHomeRec': False,
#  'hasAdditionalAttributions': False,
#  'isFeaturedListing': False,
#  'availabilityDate': None,
#  'list': True,
#  'relaxed': False}

# %%
# Keys that are in format 1 but not in format 2
list(set(houses[0].keys()) - set(houses[5].keys()))
# Out:
# ['isUserClaimingOwner',
#  'hasVideo',
#  'isUndisclosedAddress',
#  'pgapt',
#  'beds',
#  'isHomeRec',
#  'countryCurrency',
#  'price',
#  'hdpData',
#  'isZillowOwned',
#  'zestimate',
#  'sgapt',
#  'area',
#  'availabilityDate',
#  'unformattedPrice',
#  'hasAdditionalAttributions',
#  'shouldShowZestimateAsPrice',
#  'isUserConfirmedClaim',
#  'baths']

# %%
# Keys that are in format 2 but not in format 1
list(set(houses[5].keys()) - set(houses[0].keys()))
# Out:
# ['isBuilding', 'buildingName', 'units', 'lotId', 'canSaveBuilding']

# %% [markdown]
# ### Data Storage

# %%
df = pd.DataFrame(houses)

# %% [markdown]
# #### Format 1

# %%
df1 = df.loc[~df.index.isin(diff)].dropna(axis=1)
df1.head()
# Out:
#        zpid        id providerListingId  \
# 0  16840523  16840523     2jk63y6wvq97v
# 1  16841605  16841605     5c40hnjt15rhu
# 2  16835310  16835310     3kt40njpy9egr
# 3  16841647  16841647     4ntpbcue4521k
# 4  16848965  16848965     2eamy58sb36ta
#
#                                               imgSrc  hasImage  \
# 0  https://photos.zillowstatic.com/fp/4982c956876...      True
# 1  https://photos.zillowstatic.com/fp/f9ae05223db...      True
# 2  https://photos.zillowstatic.com/fp/aafbd46ba0d...      True
# 3  https://photos.zillowstatic.com/fp/b43415026e1...      True
# 4  https://photos.zillowstatic.com/fp/d9c0f3aa2dd...      True
#
#                                            detailUrl statusType  \
# 0  https://www.zillow.com/homedetails/8441-Via-Ma...   FOR_RENT
# 1  https://www.zillow.com/homedetails/8529-Villa-...   FOR_RENT
# 2  https://www.zillow.com/homedetails/3362-Via-Al...   FOR_RENT
# 3  https://www.zillow.com/homedetails/8545-Villa-...   FOR_RENT
# 4  https://www.zillow.com/homedetails/7428-Eads-A...   FOR_RENT
#
#            statusText countryCurrency      price  ...    pgapt     sgapt  \
# 0  Apartment for rent               $  $2,890/mo  ...  ForRent  For Rent
# 1  Apartment for rent               $  $2,400/mo  ...  ForRent  For Rent
# 2  Townhouse for rent               $  $3,300/mo  ...  ForRent  For Rent
# 3  Apartment for rent               $  $2,450/mo  ...  ForRent  For Rent
# 4      House for rent               $  $7,300/mo  ...  ForRent  For Rent
#
#   shouldShowZestimateAsPrice has3DModel hasVideo isHomeRec  \
# 0                      False      False    False     False
# 1                      False      False    False     False
# 2                      False      False    False     False
# 3                      False      False    False     False
# 4                      False      False    False     False
#
#   hasAdditionalAttributions  isFeaturedListing  list relaxed
# 0                     False              False  True   False
# 1                     False              False  True   False
# 2                     False              False  True   False
# 3                     False              False  True   False
# 4                     False              False  True   False
#
# [5 rows x 36 columns]

# %%
fname = "zillow_format_1.csv"
if os.path.isfile(fname):
    past = pd.read_csv(fname)
    past['providerListingId'] = past['providerListingId'].astype(str)
    new = past.merge(df1, on='providerListingId', how='left')
    new.to_csv("zillow_format_1.csv", index=False)
else:
    df1.to_csv("zillow_format_1.csv", index=False)

# %% [markdown]
# #### Format 2

# %%
df2 = df.loc[df.index.isin(diff)].dropna(axis=1)
df2.head()
# Out:
#                     zpid                    id providerListingId  \
# 5   32.86568--117.235725  32.86568--117.235725     12e0rmdse6tpe
# 6   32.841976--117.27955  32.841976--117.27955     1b6vkhb2936ea
# 7   32.86502--117.232925  32.86502--117.232925     3bzs376h3c6vn
# 9    32.84052--117.27974   32.84052--117.27974     3kmqscq5k7u52
# 11  32.857582--117.23244  32.857582--117.23244     2zxr60u8g43e8
#
#                                                imgSrc  hasImage  \
# 5   https://photos.zillowstatic.com/fp/c16331bf1be...      True
# 6   https://photos.zillowstatic.com/fp/025e0ccd6d5...      True
# 7   https://photos.zillowstatic.com/fp/f65a9fa5785...      True
# 9   https://photos.zillowstatic.com/fp/1e2aa221cb5...      True
# 11  https://photos.zillowstatic.com/fp/790a594efb8...      True
#
#                                             detailUrl statusType  \
# 5     /b/solazzo-apartments-homes-la-jolla-ca-5Xk5YK/   FOR_RENT
# 6   /b/ocean-house-on-prospect-apartment-homes-la-...   FOR_RENT
# 7               /b/village-square-la-jolla-ca-5XjSbh/   FOR_RENT
# 9                     /b/prospect-la-jolla-ca-9MjFwv/   FOR_RENT
# 11        /b/la-jolla-park-villas-la-jolla-ca-5fQhgk/   FOR_RENT
#
#                                  statusText  \
# 5                  Solazzo Apartments Homes
# 6   Ocean House on Prospect Apartment Homes
# 7                            Village Square
# 9                                  Prospect
# 11                                 For Rent
#
#                                  address                   addressStreet  ...  \
# 5   8506 Villa La Jolla Dr, La Jolla, CA  8506 Villa La Jolla Dr   # 281  ...
# 6          400 Prospect St, La Jolla, CA      400 Prospect St   Unit 401  ...
# 7        8683 Via Mallorca, La Jolla, CA          8683 Via Mallorca # 71  ...
# 9          315 Prospect St, La Jolla, CA         315 Prospect St   # 327  ...
# 11         8368 Via Sonoma, La Jolla, CA          8368 Via Sonoma Unit E  ...
#
#                                          variableData isSaved has3DModel  \
# 5   {'type': 'TIME_ON_INFO', 'text': 'Updated yest...   False      False
# 6   {'type': 'TIME_ON_INFO', 'text': 'Updated yest...   False      False
# 7   {'type': 'TIME_ON_INFO', 'text': 'Updated yest...   False      False
# 9              {'type': 'TIME_ON_INFO', 'text': None}   False      False
# 11             {'type': '3D_HOME', 'text': '3D Tour'}   False       True
#
#    isFeaturedListing  list  relaxed         lotId  \
# 5               True  True    False  1.001554e+09
# 6               True  True    False  1.001635e+09
# 7               True  True    False  1.001483e+09
# 9               True  True    False  2.079475e+09
# 11              True  True    False  1.034336e+09
#
#                                                 units  isBuilding  \
# 5                 [{'price': '$2,830+', 'beds': '1'}]        True
# 6   [{'price': '$4,990+', 'beds': '1'}, {'price': ...        True
# 7                 [{'price': '$2,425+', 'beds': '1'}]        True
# 9   [{'price': '$3,050+', 'beds': '1'}, {'price': ...        True
# 11                [{'price': '$2,300+', 'beds': '1'}]        True
#
#     canSaveBuilding
# 5              True
# 6              True
# 7              True
# 9              True
# 11            False
#
# [5 rows x 24 columns]
